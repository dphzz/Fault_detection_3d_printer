# %%
from octorest import OctoRest

# %%
def make_client(url, apikey):
     """Creates and returns an instance of the OctoRest client.

     Args:
         url - the url to the OctoPrint server
         apikey - the apikey from the OctoPrint server found in settings
     """
     try:
         client = OctoRest(url=url, apikey=apikey)
         return client
     except ConnectionError as ex:
         # Handle exception as you wish
         print(ex)

# %%
api_key = '8F42025DDA1C4CBE9C27398BEE3162A7'
url = 'http://192.168.1.7'
prusa_printer = make_client(url, api_key)

# %%
prusa_printer.connection_info()
# Out:
# {'current': {'baudrate': 250000,
#   'port': '/dev/ttyUSB0',
#   'printerProfile': '_default',
#   'state': 'Operational'},
#  'options': {'baudratePreference': None,
#   'baudrates': [250000, 230400, 115200, 57600, 38400, 19200, 9600],
#   'portPreference': '/dev/ttyUSB0',
#   'ports': ['/dev/ttyUSB0'],
#   'printerProfilePreference': '_default',
#   'printerProfiles': [{'id': '_default', 'name': 'Clone i3'}]}}

# %%
prusa_printer.files()
# Out:
# {'files': [{'children': [],
#    'display': 'Unload',
#    'name': 'Unload',
#    'origin': 'local',
#    'path': 'Unload',
#    'refs': {'resource': 'http://192.168.1.7/api/files/local/Unload'},
#    'size': 293,
#    'type': 'folder',
#    'typePath': ['folder']},
#   {'date': 1651658542,
#    'display': 'helmet_buckle_fixed.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 46.169,
#      'height': 3.02,
#      'width': 28.276000000000003},
#     'estimatedPrintTime': 356.04592350203717,
#     'filament': {'tool0': {'length': 429.30406999999997, 'volume': 0.0}},
#     'printingArea': {'maxX': 88.138,
#      'maxY': 127.282,
#      'maxZ': 3.02,
#      'minX': 59.862,
#      'minY': 81.113,
#      'minZ': 0.0}},
#    'hash': '2630ad8f5491412b051807f61a588669b151708c',
#    'name': 'helmet_buckle_fixed.gcode',
#    'origin': 'local',
#    'path': 'helmet_buckle_fixed.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651659235.360141,
#      'printTime': 679.6820823349999,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/helmet_buckle_fixed.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/helmet_buckle_fixed.gcode'},
#    'size': 157164,
#    'statistics': {'averagePrintTime': {'_default': 679.6820823349999},
#     'lastPrintTime': {'_default': 679.6820823349999}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653904859,
#    'display': 'CFFFP_z_tops.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 83.866,
#      'height': 17.3,
#      'width': 68.347},
#     'estimatedPrintTime': 4474.987891369252,
#     'filament': {'tool0': {'length': 6835.7786100003705, 'volume': 0.0}},
#     'printingArea': {'maxX': 143.738,
#      'maxY': 151.933,
#      'maxZ': 17.3,
#      'minX': 75.391,
#      'minY': 68.067,
#      'minZ': 0.0}},
#    'hash': '75f278e662538431ed9de426172b76b8e898e607',
#    'name': 'CFFFP_z_tops.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_z_tops.gcode',
#    'prints': {'failure': 7,
#     'last': {'date': 1654440823.405967, 'success': False},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_z_tops.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_z_tops.gcode'},
#    'size': 3908394,
#    'statistics': {'averagePrintTime': {'_default': 7688.6524602220015},
#     'lastPrintTime': {'_default': 7688.6524602220015}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1655195300,
#    'display': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 20.846999999999994,
#      'height': 9.26,
#      'width': 20.913999999999987},
#     'estimatedPrintTime': 185.67257073945964,
#     'filament': {'tool0': {'length': 183.46944000000016, 'volume': 0.0}},
#     'printingArea': {'maxX': 117.567,
#      'maxY': 117.574,
#      'maxZ': 9.26,
#      'minX': 96.653,
#      'minY': 96.727,
#      'minZ': 0.0}},
#    'hash': 'e49dbe16708f6ad753f286fab4b0c8d6b2f0c50f',
#    'name': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1655195888.9966955,
#      'printTime': 528.3960549389994,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_E3D_V6_insert_fine_thread_modified_rev2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_E3D_V6_insert_fine_thread_modified_rev2.gcode'},
#    'size': 445126,
#    'statistics': {'averagePrintTime': {'_default': 528.3960549389994},
#     'lastPrintTime': {'_default': 528.3960549389994}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653886346,
#    'display': 'Fan_upgrade_alittlebigger.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 64.43400000000001,
#      'height': 17.5,
#      'width': 66.58000000000001},
#     'estimatedPrintTime': 3210.0537721259193,
#     'filament': {'tool0': {'length': 3361.4513999999995, 'volume': 0.0}},
#     'printingArea': {'maxX': 138.973,
#      'maxY': 139.751,
#      'maxZ': 17.5,
#      'minX': 72.393,
#      'minY': 75.317,
#      'minZ': 0.0}},
#    'hash': '73b1c49d5cf656ea356e6a2be34047a91e1b2e5a',
#    'name': 'Fan_upgrade_alittlebigger.gcode',
#    'origin': 'local',
#    'path': 'Fan_upgrade_alittlebigger.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1653891527.6185844,
#      'printTime': 4950.414100218,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/Fan_upgrade_alittlebigger.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/Fan_upgrade_alittlebigger.gcode'},
#    'size': 1041992,
#    'statistics': {'averagePrintTime': {'_default': 4950.414100218},
#     'lastPrintTime': {'_default': 4950.414100218}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658459160,
#    'display': 'PETG_Mr_Phone_Carrier_continue.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 137.568,
#      'height': 60.0,
#      'width': 66.481},
#     'estimatedPrintTime': 5618.922439123157,
#     'filament': {'tool0': {'length': 17148.930940000213, 'volume': 0.0}},
#     'printingArea': {'maxX': 150.434,
#      'maxY': 180.716,
#      'maxZ': 60.0,
#      'minX': 83.953,
#      'minY': 43.148,
#      'minZ': 0.0}},
#    'hash': '1d874d403bc3779c5f55c271318961d3c7c33996',
#    'name': 'PETG_Mr_Phone_Carrier_continue.gcode',
#    'origin': 'local',
#    'path': 'PETG_Mr_Phone_Carrier_continue.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1658461587.903456, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/PETG_Mr_Phone_Carrier_continue.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/PETG_Mr_Phone_Carrier_continue.gcode'},
#    'size': 6541612,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1656390619,
#    'display': 'ice_dragron_continue.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 162.708,
#      'height': 24.94,
#      'width': 161.54000000000002},
#     'estimatedPrintTime': 13827.851914991898,
#     'filament': {'tool0': {'length': 17711.063599999292, 'volume': 0.0}},
#     'printingArea': {'maxX': 190.77,
#      'maxY': 191.045,
#      'maxZ': 24.94,
#      'minX': 29.23,
#      'minY': 28.337,
#      'minZ': 0.0}},
#    'hash': 'd5be0fe6ad42409bdde93c1bcead0776222e10f7',
#    'name': 'ice_dragron_continue.gcode',
#    'origin': 'local',
#    'path': 'ice_dragron_continue.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1656602705.1419346,
#      'printTime': 28982.663224964002,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/ice_dragron_continue.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/ice_dragron_continue.gcode'},
#    'size': 46455719,
#    'statistics': {'averagePrintTime': {'_default': 28982.663224964002},
#     'lastPrintTime': {'_default': 28982.663224964002}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658820640,
#    'display': 'CFFFP_Clamp_wNut_6x6mm_hollow.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 27.534999999999997,
#      'height': 6.1,
#      'width': 31.97},
#     'estimatedPrintTime': 276.74864914411876,
#     'filament': {'tool0': {'length': 284.26000000000033, 'volume': 0.0}},
#     'printingArea': {'maxX': 125.98,
#      'maxY': 124.005,
#      'maxZ': 6.1,
#      'minX': 94.01,
#      'minY': 96.47,
#      'minZ': 0.0}},
#    'hash': 'd9e3c810bc18f463cb2cec7debc6c2fc02c99b7e',
#    'name': 'CFFFP_Clamp_wNut_6x6mm_hollow.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Clamp_wNut_6x6mm_hollow.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1658821352.2284362,
#      'printTime': 708.1823027120045,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Clamp_wNut_6x6mm_hollow.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Clamp_wNut_6x6mm_hollow.gcode'},
#    'size': 162633,
#    'statistics': {'averagePrintTime': {'_default': 708.1823027120045},
#     'lastPrintTime': {'_default': 708.1823027120045}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651585958,
#    'display': 'CFFFP_TUSH-6000.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 111.827,
#      'height': 7.45,
#      'width': 139.0},
#     'estimatedPrintTime': 9215.586641792988,
#     'filament': {'tool0': {'length': 9378.592489999128, 'volume': 0.0}},
#     'printingArea': {'maxX': 181.5,
#      'maxY': 180.684,
#      'maxZ': 7.45,
#      'minX': 42.5,
#      'minY': 68.857,
#      'minZ': 0.0}},
#    'hash': '0eb4f3aa37d7a6f68d119020cfb5ca25f29cee83',
#    'name': 'CFFFP_TUSH-6000.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_TUSH-6000.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651607363.8481574,
#      'printTime': 10138.934625650001,
#      'success': True},
#     'success': 2},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_TUSH-6000.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_TUSH-6000.gcode'},
#    'size': 1487389,
#    'statistics': {'averagePrintTime': {'_default': 10104.0537113705},
#     'lastPrintTime': {'_default': 10138.934625650001}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1659712950,
#    'display': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2_perfect_one.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 20.79700000000001,
#      'height': 9.26,
#      'width': 20.873999999999995},
#     'estimatedPrintTime': 197.7694396568966,
#     'filament': {'tool0': {'length': 183.3011799999999, 'volume': 0.0}},
#     'printingArea': {'maxX': 117.547,
#      'maxY': 117.549,
#      'maxZ': 9.26,
#      'minX': 96.673,
#      'minY': 96.752,
#      'minZ': 0.0}},
#    'hash': '5f186c0850d6cca38f175fdd757098deb5d882a0',
#    'name': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2_perfect_one.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_E3D_V6_insert_fine_thread_modified_rev2_perfect_one.gcode',
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_E3D_V6_insert_fine_thread_modified_rev2_perfect_one.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_E3D_V6_insert_fine_thread_modified_rev2_perfect_one.gcode'},
#    'size': 461650,
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654049105,
#    'display': 'CFFFP_stringing_inner_wall_first.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 512.2555551283422,
#     'filament': {'tool0': {'length': 284.37861000000055, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': 'a1cccd1f57c1438e4130d80be20f9e6db065202d',
#    'name': 'CFFFP_stringing_inner_wall_first.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_inner_wall_first.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654086816.3463683,
#      'printTime': 786.7406898370002,
#      'success': True},
#     'success': 3},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_inner_wall_first.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_inner_wall_first.gcode'},
#    'size': 672326,
#    'statistics': {'averagePrintTime': {'_default': 879.6958354779999},
#     'lastPrintTime': {'_default': 786.7406898370002}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658229414,
#    'display': 'CFFFP_coaster_bts.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 94.48,
#      'height': 3.9,
#      'width': 94.48000000000002},
#     'estimatedPrintTime': 5330.451095128755,
#     'filament': {'tool0': {'length': 4291.061360000016, 'volume': 0.0}},
#     'printingArea': {'maxX': 157.246,
#      'maxY': 157.239,
#      'maxZ': 3.9,
#      'minX': 62.766,
#      'minY': 62.759,
#      'minZ': 0.0}},
#    'hash': '99febf497f8d5323c3e72ea7d29b80d4150a547b',
#    'name': 'CFFFP_coaster_bts.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_coaster_bts.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1658235419.6971476,
#      'printTime': 6002.332371558994,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_coaster_bts.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_coaster_bts.gcode'},
#    'size': 983801,
#    'statistics': {'averagePrintTime': {'_default': 6002.332371558994},
#     'lastPrintTime': {'_default': 6002.332371558994}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658474995,
#    'display': 'CFFFP_Body.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 53.187,
#      'height': 66.9,
#      'width': 154.26999999999998},
#     'estimatedPrintTime': 15569.886831772184,
#     'filament': {'tool0': {'length': 34125.47571000175, 'volume': 0.0}},
#     'printingArea': {'maxX': 188.128,
#      'maxY': 140.238,
#      'maxZ': 66.9,
#      'minX': 33.858,
#      'minY': 87.051,
#      'minZ': 0.0}},
#    'hash': '598b8a672a5a4bdcff7469dd6195cc936e589d10',
#    'name': 'CFFFP_Body.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Body.gcode',
#    'prints': {'failure': 2,
#     'last': {'date': 1658493660.2008746, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Body.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Body.gcode'},
#    'size': 5393263,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654159824,
#    'display': 'CFFFP_rotho_box_evo_total_44l_-_lid_clip.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 35.05,
#      'height': 10.1,
#      'width': 42.27300000000001},
#     'estimatedPrintTime': 639.0127578431011,
#     'filament': {'tool0': {'length': 871.7743600000002, 'volume': 0.0}},
#     'printingArea': {'maxX': 131.145,
#      'maxY': 127.532,
#      'maxZ': 10.1,
#      'minX': 88.872,
#      'minY': 92.482,
#      'minZ': 0.0}},
#    'hash': '9a1cf64c4d2b18aabf34d835b0eba5339052ee98',
#    'name': 'CFFFP_rotho_box_evo_total_44l_-_lid_clip.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_rotho_box_evo_total_44l_-_lid_clip.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654161022.692702,
#      'printTime': 1196.4423747940018,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_rotho_box_evo_total_44l_-_lid_clip.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_rotho_box_evo_total_44l_-_lid_clip.gcode'},
#    'size': 722445,
#    'statistics': {'averagePrintTime': {'_default': 1196.4423747940018},
#     'lastPrintTime': {'_default': 1196.4423747940018}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654534004,
#    'display': 'CFFFP_E3D_V6_insert_fine_thread_skirt.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 21.754999999999995,
#      'height': 9.26,
#      'width': 21.825000000000003},
#     'estimatedPrintTime': 186.2702055404018,
#     'filament': {'tool0': {'length': 188.39066000000017, 'volume': 0.0}},
#     'printingArea': {'maxX': 121.061,
#      'maxY': 121.124,
#      'maxZ': 9.26,
#      'minX': 99.236,
#      'minY': 99.369,
#      'minZ': 0.0}},
#    'hash': 'a201b826b8b36c340f5ead79299ddf8935760e96',
#    'name': 'CFFFP_E3D_V6_insert_fine_thread_skirt.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_E3D_V6_insert_fine_thread_skirt.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654534531.019929,
#      'printTime': 524.0117991969964,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_E3D_V6_insert_fine_thread_skirt.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_E3D_V6_insert_fine_thread_skirt.gcode'},
#    'size': 453156,
#    'statistics': {'averagePrintTime': {'_default': 524.0117991969964},
#     'lastPrintTime': {'_default': 524.0117991969964}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651382177,
#    'display': 'CFFFP_Strap_Buckle_Male_25mm_strap.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 166.251,
#      'height': 17.3,
#      'width': 63.681},
#     'estimatedPrintTime': 4794.741567556503,
#     'filament': {'tool0': {'length': 2131.9256400000168, 'volume': 0.0}},
#     'printingArea': {'maxX': 141.839,
#      'maxY': 198.952,
#      'maxZ': 17.3,
#      'minX': 78.158,
#      'minY': 32.701,
#      'minZ': 0.0}},
#    'hash': 'ee19b50c5fb38f0f8b0d1fd3ad934f0c83d98155',
#    'name': 'CFFFP_Strap_Buckle_Male_25mm_strap.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Strap_Buckle_Male_25mm_strap.gcode',
#    'prints': {'failure': 7,
#     'last': {'date': 1651401334.171727, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Strap_Buckle_Male_25mm_strap.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Strap_Buckle_Male_25mm_strap.gcode'},
#    'size': 2682936,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651329981,
#    'display': 'PI3_Red-Eyed_Crocodile_Skink_V3.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 163.172,
#      'height': 25.7,
#      'width': 157.609},
#     'estimatedPrintTime': 14748.106349584301,
#     'filament': {'tool0': {'length': 14881.89082000114, 'volume': 0.0}},
#     'printingArea': {'maxX': 179.459,
#      'maxY': 180.027,
#      'maxZ': 25.7,
#      'minX': 21.85,
#      'minY': 16.855,
#      'minZ': 0.0}},
#    'hash': 'dce062fd32f5c118849f5f07aa77df5a9d46bee9',
#    'name': 'PI3_Red-Eyed_Crocodile_Skink_V3.gcode',
#    'origin': 'local',
#    'path': 'PI3_Red-Eyed_Crocodile_Skink_V3.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651351435.034429,
#      'printTime': 21448.757623835,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/PI3_Red-Eyed_Crocodile_Skink_V3.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/PI3_Red-Eyed_Crocodile_Skink_V3.gcode'},
#    'size': 13690116,
#    'statistics': {'averagePrintTime': {'_default': 21448.757623835},
#     'lastPrintTime': {'_default': 21448.757623835}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658507188,
#    'display': 'CFFFP_earplug_cable__tidy.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 57.858000000000004,
#      'height': 20.1,
#      'width': 57.858000000000004},
#     'estimatedPrintTime': 2693.950108760936,
#     'filament': {'tool0': {'length': 5542.980009999978, 'volume': 0.0}},
#     'printingArea': {'maxX': 138.929,
#      'maxY': 138.929,
#      'maxZ': 20.1,
#      'minX': 81.071,
#      'minY': 81.071,
#      'minZ': 0.0}},
#    'hash': '13e09bc908a764ca70bfb2051ce941b0b229429e',
#    'name': 'CFFFP_earplug_cable__tidy.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_earplug_cable__tidy.gcode',
#    'prints': {'failure': 2,
#     'last': {'date': 1658552900.3632255,
#      'printTime': 4021.9732628740003,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_earplug_cable__tidy.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_earplug_cable__tidy.gcode'},
#    'size': 3818610,
#    'statistics': {'averagePrintTime': {'_default': 4021.9732628740003},
#     'lastPrintTime': {'_default': 4021.9732628740003}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654492252,
#    'display': 'CFFFP_stringing_bimetal_0.8_retract.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 17.400000000000006,
#      'height': 23.1,
#      'width': 40.39999999999999},
#     'estimatedPrintTime': 513.5768378689106,
#     'filament': {'tool0': {'length': 274.9574399999998, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.2,
#      'maxY': 118.7,
#      'maxZ': 23.1,
#      'minX': 89.8,
#      'minY': 101.3,
#      'minZ': 0.0}},
#    'hash': 'ca7a57b76e17cc52520db686688f059f294b19e9',
#    'name': 'CFFFP_stringing_bimetal_0.8_retract.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_bimetal_0.8_retract.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654498357.445109, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_bimetal_0.8_retract.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_bimetal_0.8_retract.gcode'},
#    'size': 565870,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1657781742,
#    'display': 'CFFFP_filament_roller.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 133.673,
#      'height': 14.4,
#      'width': 118.641},
#     'estimatedPrintTime': 4971.1382484155865,
#     'filament': {'tool0': {'length': 11789.224019999634, 'volume': 0.0}},
#     'printingArea': {'maxX': 169.317,
#      'maxY': 176.836,
#      'maxZ': 14.4,
#      'minX': 50.676,
#      'minY': 43.163,
#      'minZ': 0.0}},
#    'hash': 'fd0000165aac8bfd33cc99dcf1028289dbf147f7',
#    'name': 'CFFFP_filament_roller.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_filament_roller.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1657788953.5105453,
#      'printTime': 7207.1541533849995,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_filament_roller.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_filament_roller.gcode'},
#    'size': 2489789,
#    'statistics': {'averagePrintTime': {'_default': 7207.1541533849995},
#     'lastPrintTime': {'_default': 7207.1541533849995}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654331101,
#    'display': 'CFFFP_bracket_v2-Bracket.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 204.034,
#      'height': 25.5,
#      'width': 206.564},
#     'estimatedPrintTime': 12864.920118034586,
#     'filament': {'tool0': {'length': 22221.634530001644, 'volume': 0.0}},
#     'printingArea': {'maxX': 210.45,
#      'maxY': 213.584,
#      'maxZ': 25.5,
#      'minX': 3.886,
#      'minY': 9.55,
#      'minZ': 0.0}},
#    'hash': '90e97454e369dd99101b6907248770b9b458e1f4',
#    'name': 'CFFFP_bracket_v2-Bracket.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_bracket_v2-Bracket.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654345863.251537,
#      'printTime': 14751.048499104,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_bracket_v2-Bracket.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_bracket_v2-Bracket.gcode'},
#    'size': 2539818,
#    'statistics': {'averagePrintTime': {'_default': 14751.048499104},
#     'lastPrintTime': {'_default': 14751.048499104}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1614313104,
#    'display': 'PI3_MKS_case.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 159.7,
#      'height': 59.800000000000004,
#      'width': 155.69899999999998},
#     'estimatedPrintTime': 55006.29459171361,
#     'filament': {'tool0': {'length': 52000.45585997426, 'volume': 0.0}},
#     'printingArea': {'maxX': 189.064,
#      'maxY': 195.876,
#      'maxZ': 60.1,
#      'minX': 33.365,
#      'minY': 36.176,
#      'minZ': 0.3}},
#    'hash': 'f773aedcc27bbacc1cd3aa31eca03e4e8064701c',
#    'name': 'PI3_MKS_case.gcode',
#    'origin': 'local',
#    'path': 'PI3_MKS_case.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1614508045.8134043,
#      'printTime': 61919.673333489,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/PI3_MKS_case.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/PI3_MKS_case.gcode'},
#    'size': 21961083,
#    'statistics': {'averagePrintTime': {'_default': 61919.673333489},
#     'lastPrintTime': {'_default': 61919.673333489}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653293487,
#    'display': 'CFFFP_OralB_Toothbrushholder_wallmounted.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 59.81899999999999,
#      'height': 60.1,
#      'width': 47.63599999999998},
#     'estimatedPrintTime': 4785.677641203546,
#     'filament': {'tool0': {'length': 7295.000270000057, 'volume': 0.0}},
#     'printingArea': {'maxX': 133.819,
#      'maxY': 139.95,
#      'maxZ': 60.1,
#      'minX': 86.183,
#      'minY': 80.131,
#      'minZ': 0.0}},
#    'hash': '0e566bcc4bbecbef6e7555e5ed11cd70715cb4a3',
#    'name': 'CFFFP_OralB_Toothbrushholder_wallmounted.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_OralB_Toothbrushholder_wallmounted.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1653301508.0911088,
#      'printTime': 7616.787313672001,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_OralB_Toothbrushholder_wallmounted.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_OralB_Toothbrushholder_wallmounted.gcode'},
#    'size': 8472316,
#    'statistics': {'averagePrintTime': {'_default': 7616.787313672001},
#     'lastPrintTime': {'_default': 7616.787313672001}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658161091,
#    'display': 'CFFFP_rev3_print.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 56.93300000000001,
#      'height': 4.3,
#      'width': 41.93699999999998},
#     'estimatedPrintTime': 599.5610569446144,
#     'filament': {'tool0': {'length': 805.07362, 'volume': 0.0}},
#     'printingArea': {'maxX': 131.123,
#      'maxY': 139.699,
#      'maxZ': 4.3,
#      'minX': 89.186,
#      'minY': 82.766,
#      'minZ': 0.0}},
#    'hash': 'eb1281f9b40871975b6be3333de4c9bf76e79911',
#    'name': 'CFFFP_rev3_print.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_rev3_print.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1658162108.7930791,
#      'printTime': 1014.9705097159895,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_rev3_print.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_rev3_print.gcode'},
#    'size': 435271,
#    'statistics': {'averagePrintTime': {'_default': 1014.9705097159895},
#     'lastPrintTime': {'_default': 1014.9705097159895}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658164253,
#    'display': 'CFFFP_mounts_fillament_roller_guide.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 59.67999999999999,
#      'height': 34.9,
#      'width': 41.242000000000004},
#     'estimatedPrintTime': 1615.521107218715,
#     'filament': {'tool0': {'length': 2731.709159999999, 'volume': 0.0}},
#     'printingArea': {'maxX': 116.557,
#      'maxY': 140.862,
#      'maxZ': 34.9,
#      'minX': 75.315,
#      'minY': 81.182,
#      'minZ': 0.0}},
#    'hash': '2a376c39f524a72b6cf329d39726c4d58b977ff5',
#    'name': 'CFFFP_mounts_fillament_roller_guide.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_mounts_fillament_roller_guide.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1658167576.7263768,
#      'printTime': 3319.215741426,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_mounts_fillament_roller_guide.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_mounts_fillament_roller_guide.gcode'},
#    'size': 2065052,
#    'statistics': {'averagePrintTime': {'_default': 3319.215741426},
#     'lastPrintTime': {'_default': 3319.215741426}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654092256,
#    'display': 'CFFFP_stringing_high_a_bit_temp_2mm_retract_25_mm_retract.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 429.6406881790816,
#     'filament': {'tool0': {'length': 279.243510000001, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': '897c4c0029b6535daa746bbaaebaa5cbfaeb95b2',
#    'name': 'CFFFP_stringing_high_a_bit_temp_2mm_retract_25_mm_retract.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_high_a_bit_temp_2mm_retract_25_mm_retract.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654093053.669564,
#      'printTime': 793.4419748689998,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_high_a_bit_temp_2mm_retract_25_mm_retract.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_high_a_bit_temp_2mm_retract_25_mm_retract.gcode'},
#    'size': 646275,
#    'statistics': {'averagePrintTime': {'_default': 793.4419748689998},
#     'lastPrintTime': {'_default': 793.4419748689998}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653839060,
#    'display': 'Fan_upgrade.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 64.326,
#      'height': 17.5,
#      'width': 66.51999999999998},
#     'estimatedPrintTime': 3190.0746054125198,
#     'filament': {'tool0': {'length': 3349.2027899999994, 'volume': 0.0}},
#     'printingArea': {'maxX': 138.926,
#      'maxY': 139.702,
#      'maxZ': 17.5,
#      'minX': 72.406,
#      'minY': 75.376,
#      'minZ': 0.0}},
#    'hash': '301c509abf9875d223f0a2accae0163dbb6e31d3',
#    'name': 'Fan_upgrade.gcode',
#    'origin': 'local',
#    'path': 'Fan_upgrade.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1653844145.7855215,
#      'printTime': 5009.326664042999,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/Fan_upgrade.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/Fan_upgrade.gcode'},
#    'size': 1025387,
#    'statistics': {'averagePrintTime': {'_default': 5009.326664042999},
#     'lastPrintTime': {'_default': 5009.326664042999}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651370409,
#    'display': 'Helmet_buckle_small (3cm).gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 65.73899999999999,
#      'height': 6.5,
#      'width': 40.44900000000001},
#     'estimatedPrintTime': 1967.3051604180237,
#     'filament': {'tool0': {'length': 1762.8770700000034, 'volume': 0.0}},
#     'printingArea': {'maxX': 112.278,
#      'maxY': 134.529,
#      'maxZ': 6.5,
#      'minX': 71.829,
#      'minY': 68.79,
#      'minZ': 0.0}},
#    'hash': '6664da6b9ad8cfc396f5e2453ad112471c62230d',
#    'name': 'Helmet_buckle_small (3cm).gcode',
#    'origin': 'local',
#    'path': 'Helmet_buckle_small (3cm).gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651373405.6884222,
#      'printTime': 2973.7786737630004,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/Helmet_buckle_small%20%283cm%29.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/Helmet_buckle_small%20%283cm%29.gcode'},
#    'size': 1981464,
#    'statistics': {'averagePrintTime': {'_default': 2973.7786737630004},
#     'lastPrintTime': {'_default': 2973.7786737630004}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654096902,
#    'display': 'CFFFP_stringing_no_z_hop.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 428.17937472358784,
#     'filament': {'tool0': {'length': 279.243510000001, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': 'ca34b5ac03237de1d601b4084453c0f5d32c4eb9',
#    'name': 'CFFFP_stringing_no_z_hop.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_no_z_hop.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654157898.557312,
#      'printTime': 830.2319044600008,
#      'success': True},
#     'success': 3},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_no_z_hop.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_no_z_hop.gcode'},
#    'size': 646248,
#    'statistics': {'averagePrintTime': {'_default': 825.334865051335},
#     'lastPrintTime': {'_default': 830.2319044600008}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1657988911,
#    'display': 'CFFFP_snap-mount.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 41.95,
#      'height': 17.1,
#      'width': 36.39},
#     'estimatedPrintTime': 1075.6080739120302,
#     'filament': {'tool0': {'length': 1865.1940500000007, 'volume': 0.0}},
#     'printingArea': {'maxX': 143.196,
#      'maxY': 125.98,
#      'maxZ': 17.1,
#      'minX': 106.806,
#      'minY': 84.03,
#      'minZ': 0.0}},
#    'hash': 'e6bf6858bae2a1ac38a04398acefd8271d3d3eaa',
#    'name': 'CFFFP_snap-mount.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_snap-mount.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1657991246.0408792,
#      'printTime': 2217.575169504009,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_snap-mount.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_snap-mount.gcode'},
#    'size': 1730515,
#    'statistics': {'averagePrintTime': {'_default': 2217.575169504009},
#     'lastPrintTime': {'_default': 2217.575169504009}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654442893,
#    'display': 'CFFFP_3x3in-calibration-test-v3.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 86.60000000000001,
#      'height': 0.3,
#      'width': 86.60000000000001},
#     'estimatedPrintTime': 2405.4602710399713,
#     'filament': {'tool0': {'length': 1028.7204000000002, 'volume': 0.0}},
#     'printingArea': {'maxX': 153.3,
#      'maxY': 153.3,
#      'maxZ': 0.3,
#      'minX': 66.7,
#      'minY': 66.7,
#      'minZ': 0.0}},
#    'hash': 'c5f1ccc50ea371fec919e1b64c3f39ee874344ff',
#    'name': 'CFFFP_3x3in-calibration-test-v3.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_3x3in-calibration-test-v3.gcode',
#    'prints': {'failure': 12,
#     'last': {'date': 1662603122.9519324, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_3x3in-calibration-test-v3.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_3x3in-calibration-test-v3.gcode'},
#    'size': 89871,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658137495,
#    'display': 'CFFFP_y_motor_mount_ver2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 43.22999999999999,
#      'height': 23.1,
#      'width': 32.964},
#     'estimatedPrintTime': 994.3060953296042,
#     'filament': {'tool0': {'length': 1702.8001799999995, 'volume': 0.0}},
#     'printingArea': {'maxX': 128.881,
#      'maxY': 135.546,
#      'maxZ': 23.1,
#      'minX': 95.917,
#      'minY': 92.316,
#      'minZ': 0.0}},
#    'hash': 'ad58536542ec3ceb359f5a45da0c031a1abb41ec',
#    'name': 'CFFFP_y_motor_mount_ver2.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_y_motor_mount_ver2.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1658139727.9851174,
#      'printTime': 2091.629709405999,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_y_motor_mount_ver2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_y_motor_mount_ver2.gcode'},
#    'size': 814253,
#    'statistics': {'averagePrintTime': {'_default': 2091.629709405999},
#     'lastPrintTime': {'_default': 2091.629709405999}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654184739,
#    'display': 'CFFFP_stringing_fast_retract_40mm.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 17.400000000000006,
#      'height': 23.1,
#      'width': 40.39999999999999},
#     'estimatedPrintTime': 509.8846051573736,
#     'filament': {'tool0': {'length': 335.69539999999944, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.2,
#      'maxY': 118.7,
#      'maxZ': 23.1,
#      'minX': 89.8,
#      'minY': 101.3,
#      'minZ': 0.0}},
#    'hash': '0a7533f8c80e5f4572a3dd345907ebb7bab65e7b',
#    'name': 'CFFFP_stringing_fast_retract_40mm.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_fast_retract_40mm.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654185701.2655623,
#      'printTime': 958.9026154549938,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_fast_retract_40mm.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_fast_retract_40mm.gcode'},
#    'size': 821103,
#    'statistics': {'averagePrintTime': {'_default': 958.9026154549938},
#     'lastPrintTime': {'_default': 958.9026154549938}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654004858,
#    'display': 'CFFFP_thumb_wheel_m3.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 28.307999999999993,
#      'height': 7.5,
#      'width': 28.314000000000007},
#     'estimatedPrintTime': 368.960063426399,
#     'filament': {'tool0': {'length': 438.6601599999998, 'volume': 0.0}},
#     'printingArea': {'maxX': 124.158,
#      'maxY': 124.151,
#      'maxZ': 7.5,
#      'minX': 95.844,
#      'minY': 95.843,
#      'minZ': 0.0}},
#    'hash': '9b4bfa21ca31acdef137433d87d7d530529e24fa',
#    'name': 'CFFFP_thumb_wheel_m3.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_thumb_wheel_m3.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654006034.153927,
#      'printTime': 993.8349877600012,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_thumb_wheel_m3.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_thumb_wheel_m3.gcode'},
#    'size': 1073249,
#    'statistics': {'averagePrintTime': {'_default': 993.8349877600012},
#     'lastPrintTime': {'_default': 993.8349877600012}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1658246114,
#    'display': 'CFFFP_Test_Khoi_Vuong_XYZ.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 31.960000000000008,
#      'height': 20.1,
#      'width': 31.960000000000008},
#     'estimatedPrintTime': 824.5212422630684,
#     'filament': {'tool0': {'length': 1085.6974599999999, 'volume': 0.0}},
#     'printingArea': {'maxX': 125.98,
#      'maxY': 125.98,
#      'maxZ': 20.1,
#      'minX': 94.02,
#      'minY': 94.02,
#      'minZ': 0.0}},
#    'hash': 'ad07015e6736559b4f560a9b414a3fca8fabd5b6',
#    'name': 'CFFFP_Test_Khoi_Vuong_XYZ.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Test_Khoi_Vuong_XYZ.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1658247620.448104,
#      'printTime': 1503.290818761976,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Test_Khoi_Vuong_XYZ.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Test_Khoi_Vuong_XYZ.gcode'},
#    'size': 279721,
#    'statistics': {'averagePrintTime': {'_default': 1503.290818761976},
#     'lastPrintTime': {'_default': 1503.290818761976}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654090387,
#    'display': 'CFFFP_stringing_high_a_bit_temp_2mm_retract.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 419.6454260119223,
#     'filament': {'tool0': {'length': 279.243510000001, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': '3e46f40e43cc7bc7c1b86cb358a2a820c4233d11',
#    'name': 'CFFFP_stringing_high_a_bit_temp_2mm_retract.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_high_a_bit_temp_2mm_retract.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654091157.9325829,
#      'printTime': 766.8968467429995,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_high_a_bit_temp_2mm_retract.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_high_a_bit_temp_2mm_retract.gcode'},
#    'size': 646319,
#    'statistics': {'averagePrintTime': {'_default': 766.8968467429995},
#     'lastPrintTime': {'_default': 766.8968467429995}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1615211407,
#    'display': 'opto mount.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 69.676,
#      'height': 13.799999999999999,
#      'width': 81.241},
#     'estimatedPrintTime': 3912.8698955652007,
#     'filament': {'tool0': {'length': 4357.275559999964, 'volume': 0.0}},
#     'printingArea': {'maxX': 155.25,
#      'maxY': 137.685,
#      'maxZ': 14.1,
#      'minX': 74.009,
#      'minY': 68.009,
#      'minZ': 0.3}},
#    'hash': '063db4ce1786eeed9bd11fb92d01d9705d048368',
#    'name': 'opto_mount.gcode',
#    'origin': 'local',
#    'path': 'opto_mount.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1615217455.7114835,
#      'printTime': 5176.443293224999,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/opto_mount.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/opto_mount.gcode'},
#    'size': 1766080,
#    'statistics': {'averagePrintTime': {'_default': 5176.443293224999},
#     'lastPrintTime': {'_default': 5176.443293224999}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654187085,
#    'display': 'CFFFP_stringing_fast_retract_40mm_short_retract_coasting_on.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 17.400000000000006,
#      'height': 23.1,
#      'width': 40.39999999999999},
#     'estimatedPrintTime': 512.038162278105,
#     'filament': {'tool0': {'length': 319.4311899999988, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.2,
#      'maxY': 118.7,
#      'maxZ': 23.1,
#      'minX': 89.8,
#      'minY': 101.3,
#      'minZ': 0.0}},
#    'hash': '163603134076674bb7265a358e640633641a28c5',
#    'name': 'CFFFP_stringing_fast_retract_40mm_short_retract_coasting_on.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_fast_retract_40mm_short_retract_coasting_on.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654414888.9561179,
#      'printTime': 941.2866349279939,
#      'success': True},
#     'success': 3},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_fast_retract_40mm_short_retract_coasting_on.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_fast_retract_40mm_short_retract_coasting_on.gcode'},
#    'size': 840150,
#    'statistics': {'averagePrintTime': {'_default': 915.9582767460039},
#     'lastPrintTime': {'_default': 941.2866349279939}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653922952,
#    'display': 'Rail.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 71.32,
#      'height': 14.3,
#      'width': 22.26400000000001},
#     'estimatedPrintTime': 1130.2192058957012,
#     'filament': {'tool0': {'length': 1251.4583899999998, 'volume': 0.0}},
#     'printingArea': {'maxX': 121.132,
#      'maxY': 145.66,
#      'maxZ': 14.3,
#      'minX': 98.868,
#      'minY': 74.34,
#      'minZ': 0.0}},
#    'hash': '30a698dd475e9c6b1ad95c3e2229b1868e169f28',
#    'name': 'Rail.gcode',
#    'origin': 'local',
#    'path': 'Rail.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654149770.2448335, 'success': False},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/Rail.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/Rail.gcode'},
#    'size': 423263,
#    'statistics': {'averagePrintTime': {'_default': 1741.9202504470013},
#     'lastPrintTime': {'_default': 1741.9202504470013}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651498119,
#    'display': 'CFFFP_proximity_mount_rev2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 17.516999999999996,
#      'height': 22.98,
#      'width': 60.998999999999995},
#     'estimatedPrintTime': 1163.3442790952881,
#     'filament': {'tool0': {'length': 873.0646699999998, 'volume': 0.0}},
#     'printingArea': {'maxX': 140.986,
#      'maxY': 124.517,
#      'maxZ': 22.98,
#      'minX': 79.987,
#      'minY': 107.0,
#      'minZ': 0.0}},
#    'hash': '40c0ee980a9ea4f85d1b2b01159b02bd012bfea7',
#    'name': 'CFFFP_proximity_mount_rev2.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_proximity_mount_rev2.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651499894.1759195,
#      'printTime': 1770.931583918,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_proximity_mount_rev2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_proximity_mount_rev2.gcode'},
#    'size': 649796,
#    'statistics': {'averagePrintTime': {'_default': 1770.931583918},
#     'lastPrintTime': {'_default': 1770.931583918}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1655904573,
#    'display': 'CFFFP_Mr_Phone_Carrier.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 151.83,
#      'height': 60.1,
#      'width': 79.75299999999999},
#     'estimatedPrintTime': 13553.355024497832,
#     'filament': {'tool0': {'length': 25284.16631999406, 'volume': 0.0}},
#     'printingArea': {'maxX': 155.867,
#      'maxY': 188.197,
#      'maxZ': 60.1,
#      'minX': 76.114,
#      'minY': 36.367,
#      'minZ': 0.0}},
#    'hash': 'a9a9c7d633944856e0bde86d89798c5256f965b2',
#    'name': 'CFFFP_Mr_Phone_Carrier.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Mr_Phone_Carrier.gcode',
#    'prints': {'failure': 4,
#     'last': {'date': 1656925993.5030315, 'success': False},
#     'success': 4},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Mr_Phone_Carrier.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Mr_Phone_Carrier.gcode'},
#    'size': 18788696,
#    'statistics': {'averagePrintTime': {'_default': 20924.54948464025},
#     'lastPrintTime': {'_default': 21044.404562597992}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653271000,
#    'display': 'CFFFP_wire__BIG_holder_v2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 79.126,
#      'height': 8.9,
#      'width': 40.99799999999999},
#     'estimatedPrintTime': 1920.0797615333763,
#     'filament': {'tool0': {'length': 2996.072890000001, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.499,
#      'maxY': 149.566,
#      'maxZ': 8.9,
#      'minX': 89.501,
#      'minY': 70.44,
#      'minZ': 0.0}},
#    'hash': 'd3ebc9e54b2bd50639c7e90eec3b3b49a15853b5',
#    'name': 'CFFFP_wire__BIG_holder_v2.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_wire__BIG_holder_v2.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1653275465.8877773,
#      'printTime': 2830.7287143950007,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_wire__BIG_holder_v2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_wire__BIG_holder_v2.gcode'},
#    'size': 2669622,
#    'statistics': {'averagePrintTime': {'_default': 2830.7287143950007},
#     'lastPrintTime': {'_default': 2830.7287143950007}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654013620,
#    'display': 'CFFFP_stringing.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 512.7823885137267,
#     'filament': {'tool0': {'length': 284.3786400000003, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': 'c2fbc23b4190bc2edb1e6c5d706561d67ab46a22',
#    'name': 'CFFFP_stringing.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654014571.639662,
#      'printTime': 946.7475249339986,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing.gcode',
# ...
#      'maxZ': 7.98,
#      'minX': 76.13,
#      'minY': 79.034,
#      'minZ': 0.0}},
#    'hash': '6bb8565e1766710b4b4f417abe7b24ec81310132',
#    'name': 'CFFFP_PTFE_Tube_Cutter_M3_rev1.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_PTFE_Tube_Cutter_M3_rev1.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1655305079.2738087,
#      'printTime': 3794.6455909539995,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_PTFE_Tube_Cutter_M3_rev1.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_PTFE_Tube_Cutter_M3_rev1.gcode'},
#    'size': 3238067,
#    'statistics': {'averagePrintTime': {'_default': 3794.6455909539995},
#     'lastPrintTime': {'_default': 3794.6455909539995}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651326307,
#    'display': 'PI3_filament_guide.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 24.801999999999992,
#      'height': 23.9,
#      'width': 56.61099999999999},
#     'estimatedPrintTime': 1619.1957212818347,
#     'filament': {'tool0': {'length': 1860.2341400000005, 'volume': 0.0}},
#     'printingArea': {'maxX': 122.564,
#      'maxY': 103.598,
#      'maxZ': 23.9,
#      'minX': 65.953,
#      'minY': 78.796,
#      'minZ': 0.0}},
#    'hash': 'af55cb7c965395869f74630788959b2111488846',
#    'name': 'PI3_filament_guide.gcode',
#    'origin': 'local',
#    'path': 'PI3_filament_guide.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1651328897.5808747,
#      'printTime': 2530.3878390620002,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/PI3_filament_guide.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/PI3_filament_guide.gcode'},
#    'size': 787976,
#    'statistics': {'averagePrintTime': {'_default': 2530.3878390620002},
#     'lastPrintTime': {'_default': 2530.3878390620002}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654518992,
#    'display': 'CFFFP_E3D_V6_insert_fine_thread.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 19.355000000000004,
#      'height': 9.26,
#      'width': 19.425999999999988},
#     'estimatedPrintTime': 179.6622875042439,
#     'filament': {'tool0': {'length': 178.50071000000034, 'volume': 0.0}},
#     'printingArea': {'maxX': 119.862,
#      'maxY': 119.924,
#      'maxZ': 9.26,
#      'minX': 100.436,
#      'minY': 100.569,
#      'minZ': 0.0}},
#    'hash': 'dcd5fda62b637aaf8b45bfdaea3c328dcb504069',
#    'name': 'CFFFP_E3D_V6_insert_fine_thread.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_E3D_V6_insert_fine_thread.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654530114.291144,
#      'printTime': 329.4255148209995,
#      'success': True},
#     'success': 4},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_E3D_V6_insert_fine_thread.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_E3D_V6_insert_fine_thread.gcode'},
#    'size': 442374,
#    'statistics': {'averagePrintTime': {'_default': 412.0799877779991},
#     'lastPrintTime': {'_default': 329.4255148209995}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'children': [],
#    'display': 'PETG',
#    'name': 'PETG',
#    'origin': 'local',
#    'path': 'PETG',
#    'refs': {'resource': 'http://192.168.1.7/api/files/local/PETG'},
#    'size': 707519309,
#    'type': 'folder',
#    'typePath': ['folder']},
#   {'date': 1654582022,
#    'display': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 71.64999999999999,
#      'height': 12.3,
#      'width': 42.09899999999999},
#     'estimatedPrintTime': 1409.52355916119,
#     'filament': {'tool0': {'length': 1984.2008600000001, 'volume': 0.0}},
#     'printingArea': {'maxX': 131.046,
#      'maxY': 145.825,
#      'maxZ': 12.3,
#      'minX': 88.947,
#      'minY': 74.175,
#      'minZ': 0.0}},
#    'hash': 'e6ee8a8c245a09225b30ec745c56257c8a366104',
#    'name': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654584433.6218736,
#      'printTime': 2401.385868685,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1.gcode'},
#    'size': 1143748,
#    'statistics': {'averagePrintTime': {'_default': 2401.385868685},
#     'lastPrintTime': {'_default': 2401.385868685}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1657993664,
#    'display': 'CFFFP_snap-mount_2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.293000000000006,
#      'height': 17.1,
#      'width': 49.123999999999995},
#     'estimatedPrintTime': 2175.012773128938,
#     'filament': {'tool0': {'length': 3874.54758, 'volume': 0.0}},
#     'printingArea': {'maxX': 132.768,
#      'maxY': 124.843,
#      'maxZ': 17.1,
#      'minX': 83.644,
#      'minY': 84.55,
#      'minZ': 0.0}},
#    'hash': '6732418118f883d0bfd837b23df77774e1c43cc5',
#    'name': 'CFFFP_snap-mount_2.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_snap-mount_2.gcode',
#    'prints': {'failure': 2,
#     'last': {'date': 1658060573.8618438, 'success': False},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_snap-mount_2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_snap-mount_2.gcode'},
#    'size': 1548644,
#    'statistics': {'averagePrintTime': {'_default': 4662.408077619999},
#     'lastPrintTime': {'_default': 4662.408077619999}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1651402739,
#    'display': 'CFFFP_Strap_Buckle_Male_25mm_fixed.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 166.251,
#      'height': 17.3,
#      'width': 63.681},
#     'estimatedPrintTime': 5499.454418191919,
#     'filament': {'tool0': {'length': 5690.5281699998395, 'volume': 0.0}},
#     'printingArea': {'maxX': 141.839,
#      'maxY': 198.952,
#      'maxZ': 17.3,
#      'minX': 78.158,
#      'minY': 32.701,
#      'minZ': 0.0}},
#    'hash': '1d3a6536937eaaa6aeb793634061bb0d2c9cce69',
#    'name': 'CFFFP_Strap_Buckle_Male_25mm_fixed.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_Strap_Buckle_Male_25mm_fixed.gcode',
#    'prints': {'failure': 2,
#     'last': {'date': 1651410366.5772557,
#      'printTime': 6939.010434119002,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_Strap_Buckle_Male_25mm_fixed.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_Strap_Buckle_Male_25mm_fixed.gcode'},
#    'size': 3137899,
#    'statistics': {'averagePrintTime': {'_default': 6939.010434119002},
#     'lastPrintTime': {'_default': 6939.010434119002}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1656944290,
#    'display': 'CFFFP_vented_funnel.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 46.79599999999999,
#      'height': 37.7,
#      'width': 46.79900000000001},
#     'estimatedPrintTime': 1078.9508857842297,
#     'filament': {'tool0': {'length': 1130.9225300000012, 'volume': 0.0}},
#     'printingArea': {'maxX': 138.806,
#      'maxY': 133.398,
#      'maxZ': 37.7,
#      'minX': 92.007,
#      'minY': 86.602,
#      'minZ': 0.0}},
#    'hash': '4eb27599d92844c9dcdbd1f85b66282a34e2ee8e',
#    'name': 'CFFFP_vented_funnel.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_vented_funnel.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1656946808.432683,
#      'printTime': 1674.942120066,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_vented_funnel.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_vented_funnel.gcode'},
#    'size': 1897461,
#    'statistics': {'averagePrintTime': {'_default': 1674.942120066},
#     'lastPrintTime': {'_default': 1674.942120066}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1615379859,
#    'display': 'PI3_Rook.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 39.83300000000001,
#      'height': 47.800000000000004,
#      'width': 78.58500000000001},
#     'estimatedPrintTime': 3943.1246375204646,
#     'filament': {'tool0': {'length': 3710.5237099999968, 'volume': 0.0}},
#     'printingArea': {'maxX': 159.002,
#      'maxY': 119.921,
#      'maxZ': 48.1,
#      'minX': 80.417,
#      'minY': 80.088,
#      'minZ': 0.3}},
#    'hash': '0025ad5287ab884027a896b7e7c5c1d0c626e5bd',
#    'name': 'PI3_Rook.gcode',
#    'origin': 'local',
#    'path': 'PI3_Rook.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1615385060.1278226, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/PI3_Rook.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/PI3_Rook.gcode'},
#    'size': 7573671,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1652456574,
#    'display': 'string_test_fast_pyramid.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 20.689999999999998,
#      'height': 13.15,
#      'width': 32.69},
#     'estimatedPrintTime': 165.48871013076263,
#     'filament': {'tool0': {'length': 87.52238999999905,
#       'volume': 0.21051601835909797}},
#     'printingArea': {'maxX': 129.345,
#      'maxY': 126.345,
#      'maxZ': 13.15,
#      'minX': 96.655,
#      'minY': 105.655,
#      'minZ': 0.0}},
#    'hash': '00061f2bdf7ece96aee4aed8cc1e935ca746e1b1',
#    'name': 'string_test_fast_pyramid.gcode',
#    'origin': 'local',
#    'path': 'string_test_fast_pyramid.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1652456909.074722,
#      'printTime': 331.8407413679997,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/string_test_fast_pyramid.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/string_test_fast_pyramid.gcode'},
#    'size': 84971,
#    'statistics': {'averagePrintTime': {'_default': 331.8407413679997},
#     'lastPrintTime': {'_default': 331.8407413679997}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654511030,
#    'display': 'CFFFP_stringing_0.4_retract_no_coasting.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 17.400000000000006,
#      'height': 23.1,
#      'width': 40.39999999999999},
#     'estimatedPrintTime': 510.2181503817575,
#     'filament': {'tool0': {'length': 274.95743999999985, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.2,
#      'maxY': 118.7,
#      'maxZ': 23.1,
#      'minX': 89.8,
#      'minY': 101.3,
#      'minZ': 0.0}},
#    'hash': '36425d15cb8f3766c81c09c68921dd8a7ef696e2',
#    'name': 'CFFFP_stringing_0.4_retract_no_coasting.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_0.4_retract_no_coasting.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1654515734.3732255,
#      'printTime': 923.192349981,
#      'success': True},
#     'success': 2},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_0.4_retract_no_coasting.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_0.4_retract_no_coasting.gcode'},
#    'size': 565891,
#    'statistics': {'averagePrintTime': {'_default': 922.4399673065},
#     'lastPrintTime': {'_default': 923.192349981}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1653893924,
#    'display': 'Fan_upgrade_2%bigger.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 65.40299999999999,
#      'height': 17.5,
#      'width': 67.007},
#     'estimatedPrintTime': 3326.10538791969,
#     'filament': {'tool0': {'length': 3475.02146, 'volume': 0.0}},
#     'printingArea': {'maxX': 139.4,
#      'maxY': 140.19,
#      'maxZ': 17.5,
#      'minX': 72.393,
#      'minY': 74.787,
#      'minZ': 0.0}},
#    'hash': 'ebabb18410471dda1de4bfdddd35ec6fc44e939d',
#    'name': 'Fan_upgrade_2%bigger.gcode',
#    'origin': 'local',
#    'path': 'Fan_upgrade_2%bigger.gcode',
#    'prints': {'failure': 0,
#     'last': {'date': 1653899028.6506243,
#      'printTime': 5098.398549779,
#      'success': True},
#     'success': 1},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/Fan_upgrade_2%25bigger.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/Fan_upgrade_2%25bigger.gcode'},
#    'size': 1047119,
#    'statistics': {'averagePrintTime': {'_default': 5098.398549779},
#     'lastPrintTime': {'_default': 5098.398549779}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654089222,
#    'display': 'CFFFP_stringing_high_a_bit_temp.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 40.0,
#      'height': 23.1,
#      'width': 17.0},
#     'estimatedPrintTime': 512.2555551283422,
#     'filament': {'tool0': {'length': 284.37861000000055, 'volume': 0.0}},
#     'printingArea': {'maxX': 118.5,
#      'maxY': 130.0,
#      'maxZ': 23.1,
#      'minX': 101.5,
#      'minY': 90.0,
#      'minZ': 0.0}},
#    'hash': 'bebf749ec8221918214af487ab7cbb6badbd6745',
#    'name': 'CFFFP_stringing_high_a_bit_temp.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_stringing_high_a_bit_temp.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654614193.2648647,
#      'printTime': 855.9245500819961,
#      'success': True},
#     'success': 2},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_stringing_high_a_bit_temp.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_stringing_high_a_bit_temp.gcode'},
#    'size': 672514,
#    'statistics': {'averagePrintTime': {'_default': 814.7980858094984},
#     'lastPrintTime': {'_default': 855.9245500819961}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1654584958,
#    'display': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1_215temp.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 71.44999999999999,
#      'height': 12.3,
#      'width': 41.876999999999995},
#     'estimatedPrintTime': 1351.1925019153325,
#     'filament': {'tool0': {'length': 1899.6850299999999, 'volume': 0.0}},
#     'printingArea': {'maxX': 130.933,
#      'maxY': 145.725,
#      'maxZ': 12.3,
#      'minX': 89.056,
#      'minY': 74.275,
#      'minZ': 0.0}},
#    'hash': '74d7e0fdd3d38a2c83f59b23d5a99ef4ec35fb7d',
#    'name': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1_215temp.gcode',
#    'origin': 'local',
#    'path': 'CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1_215temp.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1654586363.4518507, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1_215temp.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/CFFFP_PTFE_cutting_jig_45_degrees_44.2mmL_v1_215temp.gcode'},
#    'size': 1178216,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']},
#   {'date': 1652457917,
#    'display': 'LCD_Cover_V2.gcode',
#    'gcodeAnalysis': {'dimensions': {'depth': 77.291,
#      'height': 26.75,
#      'width': 170.48499999999999},
#     'estimatedPrintTime': 18914.201959838887,
#     'filament': {'tool0': {'length': 16376.0786100002,
#       'volume': 39.38908507083583}},
#     'printingArea': {'maxX': 198.278,
#      'maxY': 157.643,
#      'maxZ': 26.75,
#      'minX': 27.793,
#      'minY': 80.352,
#      'minZ': 0.0}},
#    'hash': '2e87d54d42dd8c2b54abce58d26eae3c4dc57dfd',
#    'name': 'LCD_Cover_V2.gcode',
#    'origin': 'local',
#    'path': 'LCD_Cover_V2.gcode',
#    'prints': {'failure': 1,
#     'last': {'date': 1652458357.8173318, 'success': False},
#     'success': 0},
#    'refs': {'download': 'http://192.168.1.7/downloads/files/local/LCD_Cover_V2.gcode',
#     'resource': 'http://192.168.1.7/api/files/local/LCD_Cover_V2.gcode'},
#    'size': 3525689,
#    'statistics': {'averagePrintTime': {}, 'lastPrintTime': {}},
#    'type': 'machinecode',
#    'typePath': ['machinecode', 'gcode']}],
#  'free': 9313251328,
#  'total': 15382781952}

# %%
prusa_printer.job_info()
# Out:
# {'job': {'averagePrintTime': 3111.208006529996,
#   'estimatedPrintTime': 1985.6725398525657,
#   'filament': {'tool0': {'length': 5097.97584000007,
#     'volume': 12.262068889203142}},
#   'file': {'date': 1685766048,
#    'display': 'Cable_clip_5.gcode',
#    'name': 'Cable_clip_5.gcode',
#    'origin': 'local',
#    'path': 'PETG/Cable_clip_5.gcode',
#    'size': 1966406},
#   'lastPrintTime': 3136.371185885997,
#   'user': '_api'},
#  'progress': {'completion': 100.0,
#   'filepos': 1966406,
#   'printTime': 3136,
#   'printTimeLeft': 0,
#   'printTimeLeftOrigin': None},
#  'state': 'Operational'}
